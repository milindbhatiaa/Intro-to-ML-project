# %% [markdown]
# Import all required packages

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Read the data set and drop all rows containing NA values

# %%
df = pd.read_csv('greenbuildings.csv')
df.isna().sum()
print('Before cleaning df count =',df.shape[0])
df = df.dropna()
df.isna().sum()
print('After cleaning df count =',df.shape[0])
# Out:
# Before cleaning df count = 7894
# After cleaning df count = 7820

# %% [markdown]
# View the final dataset

# %%
df
# Out:
#       CS_PropertyID  cluster     size  empl_gr    Rent  leasing_rate  stories  \
# 0            379105        1   260300     2.22   38.56         91.39       14
# 1            122151        1    67861     2.22   28.57         87.14        5
# 2            379839        1   164848     2.22   33.31         88.94       13
# 3             94614        1    93372     2.22   35.00         97.04       13
# 4            379285        1   174307     2.22   40.69         96.58       16
# ...             ...      ...      ...      ...     ...           ...      ...
# 7889         157117     1230  1300000     1.15  137.51        100.00       41
# 7890         158379     1230    16140     1.15  152.73         75.22        8
# 7891          52316     1230    15726     1.15  158.92        100.00        6
# 7892         158124     1230    51300     1.15  198.99        100.00       12
# 7893         157086     1230  1876972     1.15  250.00         99.84       45
#
#       age  renovated  class_a  ...  green_rating  net  amenities  cd_total_07  \
# 0      16          0        1  ...             1    0          1         4988
# 1      27          0        0  ...             0    0          1         4988
# 2      36          1        0  ...             0    0          1         4988
# 3      46          1        0  ...             0    0          0         4988
# 4       5          0        1  ...             0    0          1         4988
# ...   ...        ...      ...  ...           ...  ...        ...          ...
# 7889   35          0        1  ...             0    0          0         1299
# 7890   90          1        0  ...             0    0          0         1299
# 7891   67          0        0  ...             0    0          0         1299
# 7892   91          0        0  ...             0    0          0         1299
# 7893   34          1        1  ...             0    0          1         1299
#
#       hd_total07  total_dd_07  Precipitation  Gas_Costs  Electricity_Costs  \
# 0             58         5046          42.57   0.013700           0.029000
# 1             58         5046          42.57   0.013731           0.029045
# 2             58         5046          42.57   0.013731           0.029045
# 3             58         5046          42.57   0.013731           0.029045
# 4             58         5046          42.57   0.013731           0.029045
# ...          ...          ...            ...        ...                ...
# 7889        4796         6095          48.35   0.011757           0.045457
# 7890        4796         6095          48.35   0.011757           0.045457
# 7891        4796         6095          48.35   0.011757           0.045457
# 7892        4796         6095          48.35   0.011757           0.045457
# 7893        4796         6095          48.35   0.011757           0.045457
#
#       cluster_rent
# 0            36.78
# 1            36.78
# 2            36.78
# 3            36.78
# 4            36.78
# ...            ...
# 7889         58.72
# 7890         58.72
# 7891         58.72
# 7892         58.72
# 7893         58.72
#
# [7820 rows x 23 columns]

# %% [markdown]
# Seperate DataFrame to Green and Non Green Buildings

# %%
df.isnull().sum()
df['green_rating'].value_counts()
df_green = df[df['green_rating']==1]
df_green
# Out:
#       CS_PropertyID  cluster    size  empl_gr   Rent  leasing_rate  stories  \
# 0            379105        1  260300     2.22  38.56         91.39       14
# 6            236739        6  210038     4.01  12.50         94.33       11
# 16           431225        8  409889    67.78  30.50         97.06       20
# 29           204299       11  525422     1.74  25.00         71.10       16
# 34           437486       13  378538     3.27  26.61         95.54       17
# ...             ...      ...     ...      ...    ...           ...      ...
# 7760         247971     1226  207082     2.38  50.85         88.99       10
# 7775         129467     1227  279507     0.97  50.95        100.00        8
# 7831         250091     1228  256739     2.38  57.00         86.40       10
# 7835         246952     1229   82771     2.38  59.40         93.79        9
# 7841         157078     1230  922027     1.15  85.00         99.67       45
#
#       age  renovated  class_a  ...  green_rating  net  amenities  cd_total_07  \
# 0      16          0        1  ...             1    0          1         4988
# 6      38          0        0  ...             1    0          1         2746
# 16      6          0        1  ...             1    0          0         5240
# 29     23          0        1  ...             1    0          1         1113
# 34     22          0        1  ...             1    0          1         2269
# ...   ...        ...      ...  ...           ...  ...        ...          ...
# 7760   35          1        1  ...             1    0          1          684
# 7775   40          1        1  ...             1    0          1         1813
# 7831    7          0        1  ...             1    0          1          684
# 7835   32          0        1  ...             1    0          1          684
# 7841   38          0        1  ...             1    0          0         1299
#
#       hd_total07  total_dd_07  Precipitation  Gas_Costs  Electricity_Costs  \
# 0             58         5046          42.57     0.0137             0.0290
# 6           1670         4416          25.55     0.0101             0.0289
# 16           956         6196          10.46     0.0120             0.0235
# 29          6001         7114          41.32     0.0108             0.0233
# 34          2382         4651          40.70     0.0138             0.0229
# ...          ...          ...            ...        ...                ...
# 7760        1419         2103          22.71     0.0103             0.0378
# 7775        3904         5717          45.73     0.0145             0.0327
# 7831        1419         2103          22.71     0.0103             0.0378
# 7835        1419         2103          22.71     0.0103             0.0378
# 7841        4796         6095          48.35     0.0118             0.0455
#
#       cluster_rent
# 0           36.780
# 6           17.500
# 16          25.500
# 29          22.000
# 34          25.055
# ...            ...
# 7760        36.000
# 7775        43.355
# 7831        48.205
# 7835        54.000
# 7841        58.720
#
# [679 rows x 23 columns]

# %%
df_non_green = df[df['green_rating']==0]
df_non_green
# Out:
#       CS_PropertyID  cluster     size  empl_gr    Rent  leasing_rate  stories  \
# 1            122151        1    67861     2.22   28.57         87.14        5
# 2            379839        1   164848     2.22   33.31         88.94       13
# 3             94614        1    93372     2.22   35.00         97.04       13
# 4            379285        1   174307     2.22   40.69         96.58       16
# 5             94765        1   231633     2.22   43.16         92.74       14
# ...             ...      ...      ...      ...     ...           ...      ...
# 7889         157117     1230  1300000     1.15  137.51        100.00       41
# 7890         158379     1230    16140     1.15  152.73         75.22        8
# 7891          52316     1230    15726     1.15  158.92        100.00        6
# 7892         158124     1230    51300     1.15  198.99        100.00       12
# 7893         157086     1230  1876972     1.15  250.00         99.84       45
#
#       age  renovated  class_a  ...  green_rating  net  amenities  cd_total_07  \
# 1      27          0        0  ...             0    0          1         4988
# 2      36          1        0  ...             0    0          1         4988
# 3      46          1        0  ...             0    0          0         4988
# 4       5          0        1  ...             0    0          1         4988
# 5      20          0        1  ...             0    0          1         4988
# ...   ...        ...      ...  ...           ...  ...        ...          ...
# 7889   35          0        1  ...             0    0          0         1299
# 7890   90          1        0  ...             0    0          0         1299
# 7891   67          0        0  ...             0    0          0         1299
# 7892   91          0        0  ...             0    0          0         1299
# 7893   34          1        1  ...             0    0          1         1299
#
#       hd_total07  total_dd_07  Precipitation  Gas_Costs  Electricity_Costs  \
# 1             58         5046          42.57   0.013731           0.029045
# 2             58         5046          42.57   0.013731           0.029045
# 3             58         5046          42.57   0.013731           0.029045
# 4             58         5046          42.57   0.013731           0.029045
# 5             58         5046          42.57   0.013731           0.029045
# ...          ...          ...            ...        ...                ...
# 7889        4796         6095          48.35   0.011757           0.045457
# 7890        4796         6095          48.35   0.011757           0.045457
# 7891        4796         6095          48.35   0.011757           0.045457
# 7892        4796         6095          48.35   0.011757           0.045457
# 7893        4796         6095          48.35   0.011757           0.045457
#
#       cluster_rent
# 1            36.78
# 2            36.78
# 3            36.78
# 4            36.78
# 5            36.78
# ...            ...
# 7889         58.72
# 7890         58.72
# 7891         58.72
# 7892         58.72
# 7893         58.72
#
# [7141 rows x 23 columns]

# %%
#Green Buildings
# sns.set(style="whitegrid")
plt.figure(figsize=(8, 6))
sns.histplot(df_green['Rent'], bins=30, kde=True, color='blue')


# Add labels and title
plt.xlabel("Rent")
plt.ylabel("Frequency")
plt.title("Green Buildings Rent")

# Show the plot
plt.show()

plt.figure(figsize=(8, 6))
sns.set(style="whitegrid")
sns.boxplot(data=df_green['Rent'])

# Add labels and title
plt.xlabel("Rent")
plt.title("Box Plot Using Seaborn")

# Show the plot
plt.show()

# %%
# Non Green Buildings
sns.set(style="whitegrid")
plt.figure(figsize=(8, 6))
sns.histplot(df_non_green['Rent'], bins=30, kde=True, color='blue')


# Add labels and title
plt.xlabel("Rent")
plt.ylabel("Frequency")
plt.title("Non Green Buildings Rent")

plt.show()

# plt.figure(figsize=(100, 100))
# sns.set(style="whitegrid")
# sns.boxplot(data=df_non_green['Rent'])

# # Add labels and title
# plt.xlabel("Rent")
# plt.title("Box Plot Using Seaborn")

# # Show the plot
# plt.show()

# %%
# for i in df.columns:
#     sns.set(style="whitegrid")
#     plt.figure(figsize=(8, 6))
#     sns.histplot(df_non_green[i], bins=30, kde=True, color='blue')


#     # Add labels and title
#     plt.xlabel(i)
#     plt.ylabel("Frequency")
#     plt.title(f"Non Green Buildings {i}")

#     plt.show()

# %% [markdown]
# Check Correlation of Rent against all variables in the entire dataset

# %%
#Overall data variable correlation
columns_to_drop = ['CS_PropertyID','cluster']
# correlation_matrix = df.drop(columns=columns_to_drop).corr()
correlation_matrix = df.corrwith(df['Rent'])

# Create a DataFrame with correlation values
correlation_df = pd.DataFrame({'Correlation with Rent': correlation_matrix})

plt.figure(figsize=(20, 8))  # Adjust the figure size (optional)
sns.heatmap(correlation_df, annot=True, cmap='coolwarm', fmt=".2f")

plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# Cluster Rent is the most highily corelated which we could have expected as the ret in a particular cluster should ideally be similar and closely related to the mean rent of the buildings in the cluster
#
# class_a buildings seem to have a higher positive correlation as compared to class_b buildings indicating a differce in rental income based on building class
#
# green_rating, LEED, Energystar all have slight poitive corelation with rent indicating Green Buildings in general should have a slightly higher rent
#
# Electriciy_Costs seem to be poitively correlated with rent
#
# The other pretty standard/obvious parameters affecting rent positively are:size, leasing_rate, stories
# The other pretty standard/obvious parameters affecting rent negatively are:age

# %% [markdown]
# Check Correlation of Rent against all variables of the Green Buildings in the dataset

# %%
#Green Buildings variable corelation
columns_to_drop = ['CS_PropertyID','cluster','green_rating']
# correlation_matrix = df_green.drop(columns=columns_to_drop).corr()
correlation_matrix = (df_green.drop(columns=columns_to_drop)).corrwith(df_green['Rent'])

# Create a DataFrame with correlation values
correlation_df = pd.DataFrame({'Correlation with Rent': correlation_matrix})

plt.figure(figsize=(20, 8))  # Adjust the figure size (optional)
sns.heatmap(correlation_df, annot=True, cmap='coolwarm')#, fmt=".2f")

plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# Within Green buildings,
#
# Apart from the general trend as we see in the whole dataset, we can see that stories has a negative corelation while age and renovation has a surprisingly positive correlation.
#
# Energystar seems to be draing a higher rent/positive corelation as compared to the LEED option.

# %%
#Non - Green Buildings variable corelation
columns_to_drop = ['CS_PropertyID','cluster','green_rating','LEED','Energystar']
correlation_matrix = (df_non_green.drop(columns=columns_to_drop)).corrwith(df_non_green['Rent'])

# Create a DataFrame with correlation values
correlation_df = pd.DataFrame({'Correlation with Rent': correlation_matrix})

plt.figure(figsize=(20, 8))  # Adjust the figure size (optional)
sns.heatmap(correlation_df, annot=True, cmap='coolwarm')#, fmt=".2f")

plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# Within Non-Green Buildings,
#
# We cannot see any specific new trend

# %% [markdown]
# Through our initial analyis, I can say that I do not completely agree with the "Excel Guru's" analyis as he has only considered the overall median rent of te Green vs Non Green buildings. The other factors such as class of the building (A seems to bring higher rent as compared to B and C), Electricity Costs, leasing rates , age, heating/cooling days have to be considered too.

# %%
# Age vs Rent
sns.set(style="whitegrid")
plt.figure(figsize=(8, 6))
sns.scatterplot(x=df['age'], y=df['Rent'], hue=df['green_rating'])


# Add labels and title
plt.xlabel("Age")
plt.ylabel("Rent")
plt.title("Buildings Age vs Rent")

plt.show()

# %%
# Leasing rate vs Rent
sns.set(style="whitegrid")
plt.figure(figsize=(8, 6))
sns.scatterplot(x=df['leasing_rate'], y=df['Rent'], hue=df['green_rating'])


# Add labels and title
plt.xlabel("Leasing rate")
plt.ylabel("Rent")
plt.title("Leasing rate vs Rent")

plt.show()

# %%
# Size vs Rent
sns.set(style="whitegrid")
plt.figure(figsize=(8, 6))
sns.scatterplot(x=df['size'], y=df['Rent'], hue=df['green_rating'])


# Add labels and title
plt.xlabel("Size")
plt.ylabel("Rent")
plt.title("Buildings Size vs Rent")

plt.show()

# %%
# plt.figure(figsize=(8, 6))
# sns.set(style="whitegrid")
# sns.boxplot(data=df['size'])

# # Add labels and title
# plt.xlabel("Rent")
# plt.title("Box Plot Using Seaborn")

# # Show the plot
# plt.show()

fig, axes = plt.subplots(1, 3, figsize=(12, 6))
y_limit = (min(df['size']), max(df['size']))

# Scatter plot on the first subplot
sns.boxplot(data=df['size'],ax=axes[0])
axes[0].set_xlabel("X")
axes[0].set_title("Scatter Plot 1")
axes[0].set_ylim(y_limit)

# Scatter plot on the second subplot
sns.boxplot(data=df_green['size'],ax=axes[1])
axes[1].set_xlabel("X")
axes[1].set_title("Scatter Plot 2")
axes[1].set_ylim(y_limit)

# Scatter plot on the second subplot
sns.boxplot(data=df_green['size'],ax=axes[2])
axes[2].set_xlabel("X")
axes[2].set_title("Scatter Plot 3")
axes[2].set_ylim(y_limit)

# Adjust layout and display plots
plt.tight_layout()
plt.show()

# %%
# df_final = df[df['leasing_rate']
df
# Out:
#       CS_PropertyID  cluster     size  empl_gr    Rent  leasing_rate  stories  \
# 0            379105        1   260300     2.22   38.56         91.39       14
# 1            122151        1    67861     2.22   28.57         87.14        5
# 2            379839        1   164848     2.22   33.31         88.94       13
# 3             94614        1    93372     2.22   35.00         97.04       13
# 4            379285        1   174307     2.22   40.69         96.58       16
# ...             ...      ...      ...      ...     ...           ...      ...
# 7889         157117     1230  1300000     1.15  137.51        100.00       41
# 7890         158379     1230    16140     1.15  152.73         75.22        8
# 7891          52316     1230    15726     1.15  158.92        100.00        6
# 7892         158124     1230    51300     1.15  198.99        100.00       12
# 7893         157086     1230  1876972     1.15  250.00         99.84       45
#
#       age  renovated  class_a  ...  green_rating  net  amenities  cd_total_07  \
# 0      16          0        1  ...             1    0          1         4988
# 1      27          0        0  ...             0    0          1         4988
# 2      36          1        0  ...             0    0          1         4988
# 3      46          1        0  ...             0    0          0         4988
# 4       5          0        1  ...             0    0          1         4988
# ...   ...        ...      ...  ...           ...  ...        ...          ...
# 7889   35          0        1  ...             0    0          0         1299
# 7890   90          1        0  ...             0    0          0         1299
# 7891   67          0        0  ...             0    0          0         1299
# 7892   91          0        0  ...             0    0          0         1299
# 7893   34          1        1  ...             0    0          1         1299
#
#       hd_total07  total_dd_07  Precipitation  Gas_Costs  Electricity_Costs  \
# 0             58         5046          42.57   0.013700           0.029000
# 1             58         5046          42.57   0.013731           0.029045
# 2             58         5046          42.57   0.013731           0.029045
# 3             58         5046          42.57   0.013731           0.029045
# 4             58         5046          42.57   0.013731           0.029045
# ...          ...          ...            ...        ...                ...
# 7889        4796         6095          48.35   0.011757           0.045457
# 7890        4796         6095          48.35   0.011757           0.045457
# 7891        4796         6095          48.35   0.011757           0.045457
# 7892        4796         6095          48.35   0.011757           0.045457
# 7893        4796         6095          48.35   0.011757           0.045457
#
#       cluster_rent
# 0            36.78
# 1            36.78
# 2            36.78
# 3            36.78
# 4            36.78
# ...            ...
# 7889         58.72
# 7890         58.72
# 7891         58.72
# 7892         58.72
# 7893         58.72
#
# [7820 rows x 23 columns]

# %%
# median_age = df.groupby(['age','green_rating'])['Rent'].median().reset_index()
# # Age vs Rent
# sns.set(style="whitegrid")
# plt.figure(figsize=(8, 6))
# sns.lineplot(x=median_age['age'], y=median_age['Rent'], hue=median_age['green_rating'])


# # Add labels and title
# plt.xlabel("Age")
# plt.ylabel("Rent")
# plt.title("Buildings Age vs Rent")

# plt.show()

# %%
#We will a leaing rate of atleast 20% and a size of atleast 200k since we are talking about at huge15 story mix use building.


# df_final = df[(df['age'] < 30) & (df['class_a'] == 1) & (df['leasing_rate'] > 20) & (df['size'] > 200000)]
df_final = df[(df['leasing_rate'] > 20) & (df['size'] > 240000)]# & (df['stories'] > 10)]
df_final.groupby(['green_rating','class_a'])[['Rent','leasing_rate','size']].median()

# df[df['size']  > 200000]['size'].describe()
# df['age'].describe()
# Out:
#                        Rent  leasing_rate      size
# green_rating class_a
# 0            0        24.00        90.600  407000.0
#              1        26.43        93.360  492131.0
# 1            0        18.90        95.565  388476.5
#              1        27.00        93.450  419619.0

# %%
print('Total cost of construction of green building = ',(100000000 + 0.05 * 100000000))
print('Total cost of construction of normal building = ',(100000000))
# print('Total income from class a green building per year = ',(27.43 * 250000))
# print('Total income from class a normal building per year = ',(27 * 250000))
print('Class A Green - Class A Normal = 1.43$ per sq.ft')
print('Non class A Green - Non class A Normal = -3.95$ per sq.ft')
print('Excess income per year',(1.43*250000))
print('Years taken to get back the money = ',(5000000/357500))
# Out:
# Total cost of construction of green building =  105000000.0
# Total cost of construction of normal building =  100000000
# Class A Green - Class A Normal = 1.43$ per sq.ft
# Non class A Green - Non class A Normal = -3.95$ per sq.ft
# Excess income per year 357500.0
# Years taken to get back the money =  13.986013986013987
